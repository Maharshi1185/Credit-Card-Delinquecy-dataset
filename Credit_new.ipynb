# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df1=pd.read_csv("credit_card.csv")

# %%
df1.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2     3913.0     3102.0      689.0        0.0        0.0
# 1      0      2     2682.0     1725.0     2682.0     3272.0     3455.0
# 2      0      0    29239.0    14027.0    13559.0    14331.0    14948.0
# 3      0      0    46990.0    48233.0    49291.0    28314.0    28959.0
# 4      0      0     8617.0     5670.0    35835.0    20940.0    19146.0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
df1.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_1         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df1["ID"].nunique()
# Out:
# 30000

# %%
df1.drop("ID",axis=1,inplace=True)

# %%
sns.boxplot(df1["DEFAULT"],df1["LIMIT_BAL"])
plt.show()

# %%
sns.countplot(df1["SEX"],hue=df1["DEFAULT"])
plt.show()

# %%
sns.countplot(df1["EDUCATION"],hue=df1["DEFAULT"])
plt.show()

# %%
sns.countplot(df1["MARRIAGE"],hue=df1["DEFAULT"])
plt.show()

# %%
sns.boxplot(df1["DEFAULT"],df1["AGE"])
plt.show()

# %%
sns.countplot(df1["PAY_1"],hue=df1["DEFAULT"])

# %%
sns.countplot(df1["PAY_2"],hue=df1["DEFAULT"])

# %%
df1["NEW_BILL"]=(df1["BILL_AMT1"]+df1["BILL_AMT2"]+df1["BILL_AMT3"]+df1["BILL_AMT4"]+df1["BILL_AMT5"]+df1["BILL_AMT6"])/6

# %%
df1[["NEW_BILL","DEFAULT"]].corr()
# Out:
#           NEW_BILL   DEFAULT
# NEW_BILL  1.000000 -0.012691
# DEFAULT  -0.012691  1.000000

# %%
df1.duplicated().sum()
# Out:
# 35

# %%
df1.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'DEFAULT',
#        'NEW_BILL'],
#       dtype='object')

# %%
cols=["LIMIT_BAL","AGE",'BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6','PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',]

# %%
for i in cols:
    sns.boxplot(df1["DEFAULT"],df1[i])
    plt.show()

# %%
a=sns.boxplot(df1["LIMIT_BAL"])

# %%
a=df1["LIMIT_BAL"].transform(lambda x: x**0.1)
sns.boxplot(a)
plt.show()

# %%
b=df1["BILL_AMT1"].transform(lambda x: x**0.2)
sns.boxplot(b)
plt.show()
# Out:
# C:\Users\Maharshi\Anaconda3\lib\site-packages\numpy\core\numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
b=df1["PAY_AMT1"].transform(lambda x: np.log(x))
sns.boxplot(b)
plt.show()

# %%
sns.distplot(df1["PAY_AMT1"]**0.05)

# %%
colo=["SEX","EDUCATION","MARRIAGE",'PAY_1', 'PAY_2','PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# %%
for i in colo:
    sns.barplot(df1[i],df1["DEFAULT"])
    plt.show()

# %%
for i in colo:
    sns.countplot(df1[i],hue=df1["DEFAULT"])
    plt.show()

# %%
sns.distplot(df1["LIMIT_BAL"])

# %%
for i in cols:
    sns.distplot(df1[i])
    plt.show()

# %%
df1.hist()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=100)

# %%
x=df1.drop("DEFAULT",axis=1)
y=df1["DEFAULT"]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

model=rf.fit(xtrain,ytrain)

# %%
ypred=model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.8143333333333334

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4663
#            1       0.66      0.35      0.45      1337
#
#     accuracy                           0.81      6000
#    macro avg       0.75      0.65      0.67      6000
# weighted avg       0.80      0.81      0.79      6000

# %%
df1["EDUCATION"].replace(5,4,inplace=True)
df1["EDUCATION"].replace(6,4,inplace=True)
df1["EDUCATION"].replace(0,4,inplace=True)

# %%
df1["EDUCATION"].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: EDUCATION, dtype: int64

# %%
df1["MARRIAGE"].replace(0,3,inplace=True)

# %%
df1["MARRIAGE"].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      377
# Name: MARRIAGE, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
scaled_train=pd.DataFrame(sc.fit_transform(xtrain),columns=xtrain.columns)

# %%
scaled_test=pd.DataFrame(sc.transform(xtest),columns=xtest.columns)

# %%
mo=rf.fit(scaled_train,ytrain)

# %%
ypro=mo.predict(scaled_test)

# %%
accuracy_score(ytest,ypro)
# Out:
# 0.8161666666666667

# %%
df2=df1.copy(deep=True)

# %%
df2["LIMIT_BAL"]=df1["LIMIT_BAL"].transform(lambda x: x**0.1)

# %%
df2["BILL_AMT1"]=df2["BILL_AMT1"].transform(lambda x : x**0.2)

# %%
c=df1["BILL_AMT4"].transform(lambda x:x**0.2)
sns.boxplot(c)
# Out:
# C:\Users\Jatin\Anaconda3\lib\site-packages\numpy\core\numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
df2["BILL_AMT2"]=df2["BILL_AMT2"].transform(lambda x:x**0.2)

# %%
df2["BILL_AMT3"]=df2["BILL_AMT3"].transform(lambda x:x**0.2)

# %%
df2["BILL_AMT4"]=df2["BILL_AMT4"].transform(lambda x:x**0.2)

# %%
df2["BILL_AMT5"]=df2["BILL_AMT5"].transform(lambda x:x**0.2)

# %%
df2["BILL_AMT6"]=df2["BILL_AMT6"].transform(lambda x:x**0.2)

# %%
Q1=df1.quantile(0.25)
Q3=df1.quantile(0.75)

# %%
IQR=q3-q1

# %%
df2[(df2 < (Q1 - 1.5 * IQR)) |(df2 > (Q3 + 1.5 * IQR))].count()
# Out:
# LIMIT_BAL       0
# SEX             0
# EDUCATION     468
# MARRIAGE        0
# AGE           272
# PAY_1        3130
# PAY_2        4410
# PAY_3        4209
# PAY_4        3508
# PAY_5        2968
# PAY_6        3079
# BILL_AMT1       0
# BILL_AMT2       0
# BILL_AMT3       0
# BILL_AMT4       0
# BILL_AMT5       0
# BILL_AMT6       0
# PAY_AMT1     2745
# PAY_AMT2     2714
# PAY_AMT3     2598
# PAY_AMT4     2994
# PAY_AMT5     2945
# PAY_AMT6     2958
# DEFAULT      6636
# NEW_BILL     2575
# dtype: int64

# %%
v=df1["AGE"].transform(lambda x : np.log(x))
sns.boxplot(v)

# %%
df2["AGE"]=df2["AGE"].transform(lambda x : np.log(x))

# %%
df2.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   2.692173    2          2         1  3.178054      2      2     -1     -1
# 1   3.220462    2          2         2  3.258097     -1      2      0      0
# 2   3.129135    2          2         2  3.526361      0      0      0      0
# 3   2.950509    2          2         1  3.610918      0      0      0      0
# 4   2.950509    1          2         1  4.043051     -1      0     -1      0
#
#    PAY_5  ...               BILL_AMT5                BILL_AMT6  PAY_AMT1  \
# 0     -2  ...                      0j                       0j         0
# 1      0  ...  (5.101402731173341+0j)  (5.0427816028042995+0j)         0
# 2      0  ...  (6.837803525911983+0j)   (6.891924207065686+0j)      1518
# 3      0  ...   (7.80470895023287+0j)   (7.836148876679203+0j)      2000
# 4      0  ...  (7.184815344785271+0j)   (7.183689198124168+0j)      2000
#
# ...

# %%
np.dtype(df2["BILL_AMT1"])
# Out:
# dtype('int64')

# %%
df2["BILL_AMT1"]=df2["BILL_AMT1"].astype("int64")

# %%
df2["BILL_AMT2"]=df2["BILL_AMT2"].astype("int64")

# %%
df2.drop("BILL_AMT!",axis=1,inplace=True)

# %%
df2["BILL_AMT3"]=df2["BILL_AMT3"].astype("int64")

# %%
df2["BILL_AMT4"]=df2["BILL_AMT4"].astype("int64")
df2["BILL_AMT5"]=df2["BILL_AMT5"].astype("int64")
df2["BILL_AMT6"]=df2["BILL_AMT6"].astype("int64")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# LIMIT_BAL    30000 non-null float64
# SEX          30000 non-null int64
# EDUCATION    30000 non-null int64
# MARRIAGE     30000 non-null int64
# AGE          30000 non-null float64
# PAY_1        30000 non-null int64
# PAY_2        30000 non-null int64
# PAY_3        30000 non-null int64
# PAY_4        30000 non-null int64
# PAY_5        30000 non-null int64
# PAY_6        30000 non-null int64
# BILL_AMT1    30000 non-null int64
# BILL_AMT2    30000 non-null int64
# BILL_AMT3    30000 non-null int64
# BILL_AMT4    30000 non-null int64
# BILL_AMT5    30000 non-null int64
# BILL_AMT6    30000 non-null int64
# PAY_AMT1     30000 non-null int64
# PAY_AMT2     30000 non-null int64
# PAY_AMT3     30000 non-null int64
# PAY_AMT4     30000 non-null int64
# PAY_AMT5     30000 non-null int64
# PAY_AMT6     30000 non-null int64
# DEFAULT      30000 non-null int64
# ...

# %%
df2.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   2.692173    2          2         1  3.178054      2      2     -1     -1
# 1   3.220462    2          2         2  3.258097     -1      2      0      0
# 2   3.129135    2          2         2  3.526361      0      0      0      0
# 3   2.950509    2          2         1  3.610918      0      0      0      0
# 4   2.950509    1          2         1  4.043051     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0     -2  ...          0          0         0       689         0         0
# 1      0  ...          5          5         0      1000      1000      1000
# 2      0  ...          6          6      1518      1500      1000      1000
# 3      0  ...          7          7      2000      2019      1200      1100
# 4      0  ...          7          7      2000     36681     10000      9000
#
#    PAY_AMT5  PAY_AMT6  DEFAULT      NEW_BILL
# ...

# %%
df2.drop("NEW_BILL",axis=1,inplace=True)

# %%
x=df2.drop("DEFAULT",axis=1)
y=df2["DEFAULT"]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
scaled_train=pd.DataFrame(sc.fit_transform(xtrain),columns=xtrain.columns)
scaled_test=pd.DataFrame(sc.transform(xtest),columns=xtest.columns)

# %%
modo=rf.fit(scaled_train,ytrain)

# %%
ypredo=modo.predict(scaled_test)

# %%
accuracy_score(ytest,ypredo)
# Out:
# 0.8143333333333334

# %%
print(classification_report(ytest,ypredo))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4663
#            1       0.65      0.35      0.46      1337
#
#     accuracy                           0.81      6000
#    macro avg       0.75      0.65      0.67      6000
# weighted avg       0.80      0.81      0.79      6000

# %%
cov_matrix=np.cov(scaled_df3.T)
print("covariance_matrix \n",cov_matrix) 
eig_val,eig_vec=np.linalg.eig(cov_matrix)
tot=sum(eig_val)
var_exp=[(i/tot)* 100 for i in sorted(eig_val,reverse=True)]
cum_var_exp=np.cumsum(var_exp)
print("Cumulative Variance Explained",cum_var_exp)
print(eig_val)
sorted(eig_val,reverse=True)
eigen_pairs=[(np.abs(eig_val[i]),eig_vec[:,i]) for i in range(len(eig_val))]
eigen_pairs
eigen_pairs_sorted=sorted(eigen_pairs,reverse=True)
eigen_pairs_sorted
eigen_values_sort=[eigen_pairs_sorted[i][0] for i in range(len(eig_val)) ]
eigen_vectors_sort=[eigen_pairs_sorted[i][1] for i in range(len(eig_val))]
P_reduce=np.array(eigen_vectors_sort[0:17]).transpose()
P_reduce
proj_data_pca=np.dot(scaled_df3,P_reduce)
proj_data_pca.shape
# Out:
# covariance_matrix
#  [[ 1.00003333e+00  6.82548474e-02 -2.38326383e-01 -1.18625700e-01
#    1.74989041e-01 -2.89496797e-01 -3.23808393e-01 -3.14647475e-01
#   -2.96414782e-01 -2.77242326e-01 -2.55434208e-01  4.78756163e-02
#    3.77933189e-02  4.74540484e-02  5.52675161e-02  6.93109631e-02
#    8.91527948e-02  1.79800601e-01  1.54265958e-01  1.81822175e-01
#    1.81993416e-01  1.91075923e-01  1.93609441e-01 -1.73120074e-01]
#  [ 6.82548474e-02  1.00003333e+00  1.36275740e-02 -2.85227546e-02
#   -9.35258121e-02 -5.76448004e-02 -7.07733623e-02 -6.60982597e-02
#   -6.01752442e-02 -5.50657206e-02 -4.40092552e-02 -5.00819179e-02
#   -4.96443421e-02 -3.80343317e-02 -3.36286182e-02 -2.52141282e-02
#   -1.99307798e-02 -2.42462645e-04 -1.39095602e-03 -8.59691148e-03
#   -2.22904581e-03 -1.66721737e-03 -2.76611449e-03 -3.99619098e-02]
#  [-2.38326383e-01  1.36275740e-02  1.00003333e+00 -1.36801501e-01
#    1.69161771e-01  1.12596533e-01  1.29707687e-01  1.22429282e-01
# ...

# %%
df3=df2.copy()

# %%
scaled_df3=pd.DataFrame(sc.fit_transform(df3),columns=df3.columns)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn import model_selection

# %%
LR=LogisticRegression()
NB=GaussianNB()
DT=DecisionTreeClassifier(criterion="gini",random_state=0)
RF=RandomForestClassifier(n_estimators=10,criterion="gini",random_state=0)
KNN=KNeighborsClassifier(n_neighbors=300,weights="uniform")
LR_boost=AdaBoostClassifier(base_estimator=LR,n_estimators=100,random_state=0)
DT_boost=AdaBoostClassifier(base_estimator=DT,n_estimators=100,random_state=0)
RF_boost=AdaBoostClassifier(base_estimator=RF,n_estimators=100,random_state=0)
GBoost=GradientBoostingClassifier(n_estimators=100,random_state=0)

# %%
models=[]
models.append(("LogisticRegression",LR))
models.append(("NaiveBayes",NB))
models.append(("DecisionTree",DT))
models.append(("RandomForest",RF))
models.append(("KNN",KNN))
models.append(("Boosted LogisticRegression",LR_boost))
models.append(("Boosted DecisionTree",DT_boost))
models.append(("Boosted RandomForest",RF_boost))
models.append(("Gradient Boost",GBoost))

# %%
Y=df3["DEFAULT"]
results=[]
names=[]
for name,model in models:
    kfold=model_selection.KFold(shuffle=True,n_splits=15,random_state=0) #shuffle:it shuffles data and split=no of folds
    cv_results=model_selection.cross_val_score(model,scaled_df3,Y,cv=kfold,scoring="f1_weighted")
    results.append(cv_results)
    names.append(name)
    print("%s : %f (%f)" %(name,np.mean(cv_results),np.var(cv_results,ddof=1)))
# Out:
# LogisticRegression : 1.000000 (0.000000)
# NaiveBayes : 1.000000 (0.000000)
# DecisionTree : 1.000000 (0.000000)
# RandomForest : 1.000000 (0.000000)
# KNN : 0.987626 (0.000007)
# Boosted LogisticRegression : 0.998303 (0.000002)
# Boosted DecisionTree : 1.000000 (0.000000)
# Boosted RandomForest : 1.000000 (0.000000)
# Gradient Boost : 1.000000 (0.000000)

# %%
fig=plt.figure(figsize=(10,5))
fig.suptitle("Algorithm Comaparison")
ax=fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names,rotation=45)
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.cluster import KMeans

# %%
cluster_inertia=[]
for i in range(1,15):
    model=KMeans(n_clusters=i)
    model.fit(scaled_df3)
    cluster_inertia.append(model.inertia_)

# %%
plt.figure(figsize=(10,5))
plt.plot(range(1,15),cluster_inertia,marker="o")
plt.show()

# %%
modelKM=KMeans(n_clusters=2,n_init=15,random_state=0)
modelKM.fit(proj_data_pca)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=15, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
modelKM.inertia_
# Out:
# 528285.4487441861

# %%
l=pd.DataFrame(modelKM.labels_)
l[0].value_counts()
# Out:
# 0    19134
# 1    10866
# Name: 0, dtype: int64

# %%
kmeans_1=KMeans(n_clusters=2,n_init=15,random_state=2)
kmeans_1.fit(scaled_df3.drop("DEFAULT",axis=1))
centroids_1=kmeans_1.cluster_centers_
centroids_1
centroid_df_1=pd.DataFrame(centroids_1,columns=list(scaled_df3.drop("DEFAULT",axis=1)))
centroid_df_1.T
# Out:
#                   0         1
# LIMIT_BAL  0.323947 -0.183357
# SEX        0.076877 -0.043513
# EDUCATION -0.193461  0.109500
# MARRIAGE  -0.068001  0.038489
# AGE        0.096488 -0.054613
# PAY_1     -0.605319  0.342615
# PAY_2     -0.778035  0.440373
# PAY_3     -0.801153  0.453458
# PAY_4     -0.839592  0.475215
# PAY_5     -0.860555  0.487080
# PAY_6     -0.848946  0.480510
# BILL_AMT1 -0.910610  0.515412
# BILL_AMT2 -0.961359  0.544136
# BILL_AMT3 -0.990412  0.560580
# BILL_AMT4 -1.000002  0.566008
# BILL_AMT5 -0.978964  0.554101
# BILL_AMT6 -0.916228  0.518592
# PAY_AMT1  -0.112785  0.063837
# PAY_AMT2  -0.084568  0.047866
# PAY_AMT3  -0.081047  0.045873
# PAY_AMT4  -0.061026  0.034541
# PAY_AMT5  -0.060273  0.034115
# PAY_AMT6  -0.041502  0.023491

# %%
sns.boxplot(Y,df1["BILL_AMT5"])

# %%
sns.boxplot(Y,df1["BILL_AMT4"])

# %%
sns.violinplot(Y,df1["BILL_AMT4"])

# %%
sns.barplot(Y,df1["PAY_6"])

# %%
n=["PAY_6","PAY_5","PAY_4","PAY_3","PAY_2","PAY_1"]

# %%
for i in n:
    sns.barplot(Y,df1[i])
    plt.show()

# %%
d=["BILL_AMT6","BILL_AMT5","BILL_AMT4","BILL_AMT3","BILL_AMT2","BILL_AMT1"]

# %%
for i in d:
    sns.violinplot(Y,df1[i])
    plt.show()

# %%
pd.crosstab(df1["SEX"],df1["DEFAULT"])
# Out:
# DEFAULT      0     1
# SEX
# 1         9015  2873
# 2        14349  3763

# %%
#1 male 
#2 female

# %%
2873/(9015+2873)
# Out:
# 0.2416722745625841

# %%
3763/(14349+3763)
# Out:
# 0.20776280918727916

# %%
#males will default more

# %%
pd.crosstab(df1["EDUCATION"],df1["DEFAULT"])
# Out:
# DEFAULT        0     1
# EDUCATION
# 1           8549  2036
# 2          10700  3330
# 3           3680  1237
# 4            435    33

# %%
#(1 = graduate school; 2 = university; 3 = high school; 4 = others)

# %%
#high schoolers %
